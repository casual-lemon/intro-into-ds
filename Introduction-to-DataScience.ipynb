# %% [markdown]
# # What is Jupyter Notebooks?
#
# Jupyter Notebook is a very fancy markdown editor that can run code.
# It tries to both be a viewer for markdown and execute Python or R code
# but does neither very well.

# %% [markdown]
# # What is Data Science?
#
# It's an agglomeration of programming (Python or R), statistics, and machine learning (alogrithms) used to extract useful insights and knowledge from data to be applied to a business objective.
#
# It is not well defined, and a data scientist at company A, can mean something entirely different than at company B.
#
# What differeriates a data scientist from a data analyst?
# - Data scientist works with prediction of outcomes and machine learning models
#     - really focused on getting the best performace/accuracy out of the model
# - Data analyst generates dashboards and uses general statstics analysis of data that we already have
#
# So, there is overlap between the two, but the nature of the work is a little different.

# %% [markdown]
# # Software engineering lifecycle

# %% [markdown]
# In Computer Science there is the software engineering lifecycle and it looks like this
#
# ![stages-of-software-development-process-1.png](attachment:stages-of-software-development-process-1.png)

# %% [markdown]
# ### Surprise! Data Science has one too..

# %% [markdown]
# # Data Science Lifecycle
#
# Data Science Lifecycle revolves around the use of machine learning and different analytical strategies to produce insights and predictions from information in order to acquire an enterprise objective.
#
# ![datasciencelifecycle.png](attachment:datasciencelifecycle.png)

# %% [markdown]
# # Python or R?
#
# Python is a high level programming language and is often used for its extensive thirdy party machine learning libraries.
# A lot of the machine learning libraries actually started from R. For example; Panda's DataFrames initially started in R.
#
# R is used mostly for generating descriptive statistics.
#
# You can use either of them interachangbly as well, you can put R inside of Python or Python in R.

# %% [markdown]
# # Statistics
#
# Statistics plays a large role in data science. It's helpful in determining how accuraute we are with the model.
#
# How much statstics do I need to know? .... Everything!
#
# Need to understand the testing of null hypothesis, confidence intervals, reading p-values (0.05), chi-squared tests why they're used and how to read the results.
# Statstical Regression Techinques - Linear regression, multiple linear regression, decision trees,
# Random Forests, diagnostic plots, Q-QPlots, etc.

# %%
Call:
lm(formula = sim_tot_fat ~ fat_type_factor * flour_type_factor, 
    data = doughnuts.factorial)

Residuals:
    Min      1Q  Median      3Q     Max 
-28.333  -5.958  -0.250   6.667  21.667 

Coefficients:
                                              Estimate Std. Error t value Pr(>|t|)    
(Intercept)                                     75.167      4.197  17.910  < 2e-16 ***
fat_type_factorPeanut                            3.667      5.935   0.618  0.53906    
fat_type_factorShortening                        7.167      5.935   1.207  0.23199    
fat_type_factorSunflower                       -15.167      5.935  -2.555  0.01316 *  
flour_type_factorgf                             -8.833      5.935  -1.488  0.14191    
flour_type_factorww                            -15.833      5.935  -2.668  0.00981 ** 
fat_type_factorPeanut:flour_type_factorgf        2.333      8.394   0.278  0.78198    
fat_type_factorShortening:flour_type_factorgf    3.667      8.394   0.437  0.66380    
fat_type_factorSunflower:flour_type_factorgf    -3.833      8.394  -0.457  0.64954    
fat_type_factorPeanut:flour_type_factorww       12.833      8.394   1.529  0.13154    
fat_type_factorShortening:flour_type_factorww   10.000      8.394   1.191  0.23820    
fat_type_factorSunflower:flour_type_factorww     8.500      8.394   1.013  0.31529
Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

Residual standard error: 10.28 on 60 degrees of freedom
# Out:
#   File "<ipython-input-1-50a4a1fdbf8e>", line 1
#     Call:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![qqplot.PNG](attachment:qqplot.PNG)

# %% [markdown]
# # Machine Learning
#
# Supervised & Unsupervised Machine Learning

# %% [markdown]
# Machine Learning (Algorithms) -
#
# There are four methods of machine learning...
#
# - Supervised
# - Unsupervised
# - Semi-supervised
# - Reinforcement Learning
#
# Supervised is classified into two categories of algorithms
# Basically supervised learning is when we teach or train the machine using data that is well labelled. Which means some data is already tagged with the correct answer. After that, the machine is provided with a new set of examples(data) so that the supervised learning algorithm analyses the training data(set of training examples) and produces a correct outcome from labelled data.
#
#
# You will be using either regression techinques or classification methods.
#
# Linear regression for stock market predictions
# Regression uses discrete values, like dollars, weight, numbers.
#
# Example:
# - Naive Bayes Classifiers
# - K-NN (K nearest neighbors)
# - Decision Trees
# - Support Vector Machine
#
#
# Classification: for categorizing data. Hot dog, not a hot dog. If I give you 100 pictures of a dog, then a picture of a cat can the model tell the difference between the two.
#
#
#
#
# Unsupervised Machine Learning -
#
# Unsupervised learning is the training of a machine using information that is neither classified nor labeled and allowing the algorithm to act on that information without guidance. Here the task of the machine is to group unsorted information according to similarities, patterns, and differences without any prior training of data.
# Therefore the machine is restricted to find the hidden structure in unlabeled data by itself.
# - No human interactions
#
# Clustering Types:-
# - Hierarchical clustering
# - K-means clustering
# - Principal Component Analysis
# - Singular Value Decomposition

# %% [markdown]
# ![puppy.png](attachment:puppy.png)

# %% [markdown]
# # What is the difference between a data scientist and a machine learning engineer?

# %% [markdown]
# data scientist - mostly concerned with how can i get the best tuning and performance out of my model/
# most centered around the algorithm that get implemented.
#
# Machine learning engineer overlaps with a data scientist, but you can tell them to go create a feature
# (full stack dev) they aren't necessary concerned with model tuning/performance (not primary goal).

# %% [markdown]
# # Code Example
